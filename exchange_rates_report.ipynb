# %% [markdown]
# # Отчет по курсам валют

# %%
import requests

# %%
r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')

# %%
curs = r.json()['Valute']['DZD']
curs
# Out:
# {'ID': 'R01030',
#  'NumCode': '012',
#  'CharCode': 'DZD',
#  'Nominal': 100,
#  'Name': 'Алжирских динаров',
#  'Value': 59.4608,
#  'Previous': 59.2589}
